# %%
#reading a csv file

# %%
import pandas as pd
df=pd.read_csv("stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0  GOOGLE          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
pd.read_excel("stock_data.xlsx", "Sheet1")
# Out:
#   tickers            eps  revenue price         people
# 0  GOOGLE          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
weather_data=[
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow'),
]

# %%
daf=pd.DataFrame(weather_data)

# %%
daf
# Out:
#           0   1  2      3
# 0  1/1/2017  32  6   Rain
# 1  1/2/2017  35  7  Sunny
# 2  1/3/2017  28  2   Snow

# %%
import pandas as pd

# %%
daf=pd.DataFrame(weather_data,columns=["day","temperature","windspeed","event"])

# %%
daf
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
daf[daf.temperature==daf["temperature"].max()]['day','temperature']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('day', 'temperature')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-94d1d75939f0> in <module>
# ...

# %%
df1=pd.read_csv("stock_data.csv",skiprows=1)

# %%
df1
# Out:
#   GOOGLE          27.82   87   845     larry page
# 0    WMT           4.61  484    65           n.a.
# 1   MSFT             -1   85    64     bill gates
# 2    RIL  not available   50  1023  mukesh ambani
# 3   TATA            5.6   -1  n.a.     ratan tata

# %%
df2=pd.read_csv("stock_data.csv",header=2)
df2
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1   RIL  not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
df3=pd.read_csv("stock_data.csv",header=None)
df3
# Out:
#          0              1        2      3              4
# 0  tickers            eps  revenue  price         people
# 1   GOOGLE          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4      RIL  not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df4=pd.read_csv("stock_data.csv",skiprows=1,header=None,names=["tickers","eps","revenues","prices","people"])
df4
# Out:
#   tickers            eps  revenues prices         people
# 0  GOOGLE          27.82        87    845     larry page
# 1     WMT           4.61       484     65           n.a.
# 2    MSFT             -1        85     64     bill gates
# 3     RIL  not available        50   1023  mukesh ambani
# 4    TATA            5.6        -1   n.a.     ratan tata

# %%
df5=pd.read_csv("stock_data.csv",nrows=3)
df5
# Out:
#   tickers    eps  revenue  price      people
# 0  GOOGLE  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
df=pd.read_csv("stock_data.csv",na_values=["not available","n.a."])
df
# Out:
#   tickers    eps  revenue   price         people
# 0  GOOGLE  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3     RIL    NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return "sam walton"
    return cell
df6=pd.read_csv("stock_data.csv",na_values={
    'eps':["not available","n.a."],
    'revenue':["not available","n.a.",-1]
},converters={
    'people':convert_people_cell
})
               
df6
# Out:
#   tickers    eps  revenue price         people
# 0  GOOGLE  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65     sam walton
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
#writing back to csv

# %%
df6.to_csv("new_stock.csv",index=False)

# %%
df6.to_csv("new_stockdata.csv",index=False,columns=['tickers','revenue'])

# %%
#to skip exporting the header

# %%
df6.to_csv("new_stock_data.csv",index=False,header=False)

# %%
#reading excel file

# %%
df7=pd.read_excel("stock_data.xlsx",'Sheet1')

# %%
df7
# Out:
#   tickers            eps  revenue price         people
# 0  GOOGLE          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
    if cell=="n.a.":
        return "sam walton"
    return cell
def convert_eps_cell(cell):
    if cell=="not available":
        return None
    return cell
df8=pd.read_csv("stock_data.csv",na_values={
    'eps':["not available","n.a."],
    'revenue':["not available","n.a.",-1]
},converters={
    'people':convert_people_cell,
    'eps':convert_eps_cell
})
               
df8
# Out:
#   tickers    eps  revenue price         people
# 0  GOOGLE  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65     sam walton
# 2    MSFT     -1     85.0    64     bill gates
# 3     RIL   None     50.0  1023  mukesh ambani
# 4    TATA    5.6      NaN  n.a.     ratan tata

# %%
#writing back to excel file

# %%
df8.to_excel("new_stockdata.xlsx",sheet_name="stocks",startrow=1,startcol=2)

# %%
#writing to data frames simultaneously to the same excel file, but at different sheets

# %%
df_stocks=pd.DataFrame({
    'tickers':['GOOGL','WMT','MSFT'],
    'price':[845,65,64],
    'pe':[30.37,14.26,30.97],
    'eps':[27.82,4.61,2.12]
})
df_weather=pd.DataFrame({
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'temperature':[32,35,28],
    'event':['Rain','Sunny','Snow']
})

# %%
with pd.ExcelWriter("stocks_weather.xlsx")as writer:
    df_stocks.to_excel(writer,sheet_name="stocks")
    df_weather.to_excel(writer,sheet_name="weather")
